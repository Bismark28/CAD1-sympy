# %%
from sympy import *

x, y = symbols('x, y')
f = Function('f')(x**3 + 2*x - 1)
f.diff()
# Out:
# (3*x**2 + 2)*Subs(Derivative(f(_xi_1), _xi_1), (_xi_1,), (x**3 + 2*x - 1,))

# %%
diff(f,x)
# Out:
# (3*x**2 + 2)*Subs(Derivative(f(_xi_1), _xi_1), (_xi_1,), (x**3 + 2*x - 1,))

# %%
f = x**3 + 2*x -1
diff(f,x)
# Out:
# 3*x**2 + 2

# %%
def f(x)
    return x**3 + 2*x - 1
f(x)
print('first derivative', diff(f(x),x))
print('second derivative', diff(diff((f(x),x)
# Out:
#   File "<ipython-input-5-68e1e00e0705>", line 1
#     def f(x)
#             ^
# SyntaxError: invalid syntax

# %%
diff(cos(x),x)
# Out:
# -sin(x)

# %%
diff(sin(x),x)
# Out:
# cos(x)

# %%
def f(x):
    return x/(x**3+1)
f(x)
# Out:
# x/(x**3 + 1)

# %%
diff(f(x),x)
# Out:
# -3*x**3/(x**3 + 1)**2 + 1/(x**3 + 1)

# %%
integrate(diff(f(x),x))
# Out:
# x/(x**3 + 1)

# %%
f = exp(2*x)

# %%
print(f)
# Out:
# exp(2*x)

# %%
d = integrate(f,x)
g = diff(d,x)

# %%
print (d)
print (g)
# Out:
# exp(2*x)/2
# exp(2*x)

# %%
h = integrate(diff(f,x))
print(h)
# Out:
# exp(2*x)

# %%
w, a = symbols('w, a')
integrate(x*exp(-a*x)*cos(w*x),(x, 0, oo)). simplify()
# Out:
# Piecewise(((a**2 - w**2)/(a**2 + w**2)**2, Eq(Abs(periodic_argument(polar_lift(w)**2, oo)), 0) & (Abs(periodic_argument(polar_lift(a)**2, oo)) < pi)), (Integral(x*exp(-a*x)*cos(w*x), (x, 0, oo)), True))

# %%
# one plot
u = symbols('u')
plot(sin(u), (u, 0, pi/2))

# %%
plot(2*cos(x)-2+3*sin(2*x), (x, -pi, pi));

# %%
p1 = plot(x**2, (x,-10,10))
p2 = plot(x**3, (x,-10,10))

# %% [markdown]
# c1 = 2*cos(x)-2+3*sin(2*x)
# p1 = plot(cos(x), c1,(x, -pi, pi), legend=True, show=False)
# p1[0], line_colour = r

# %%
c1 = 2*x
c2 = 3*x*2
p1 = plot(c1,c2, (x,-10,10), legend=True , show=False)
p1[0].line_color = 'r'
p1[1].line_color = 'b'
p1.show()

# %%
l = [cos(n*x) for n in range(1, 4)]
p3 = plot(*l, (x, 0, 2*pi), show=False, title = '$\cos(nx)$ for n in [1,3]', legend=['cos(x)','cos(2x)','cos(3x)'])
p3[0].line_color = 'r'
p3[1].line_color = 'b'
p3[2].line_color = 'k'
p3.show()

# %%
plotting.plot_parametric((cos(u), sin(u), (u,-5,5)))

# %%
x, y = symbols('x y')
plotting.plot3d((x*y)**2,(x,-5,5),(y,-5,5))

# %%
t = symbol('t')
c1 = plotting.plot_parametric
